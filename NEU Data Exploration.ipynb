# %%
import os
import pathlib
import tensorflow as tf
from keras.preprocessing.image import load_img, img_to_array

# %% [markdown]
# ### Data Exploration

# %%
base_dir = 'C:/Users/m477a/JupyterNote/task_prof_tsou/NEU Surface Defect Database/IMAGES'
train_dir = os.path.join(base_dir, 'train')
# validation_dir = os.path.join(base_dir, 'val')

# %%
path_data = 'C:/Users/m477a/JupyterNote/task_prof_tsou/NEU Surface Defect Database/IMAGES/train'
crz = path_data + '/crazing'
inc = path_data + '/inclusion'
ptc = path_data + '/patches'
pts = path_data + '/pitted_surface'
rds = path_data + '/rolled-in_scale'
sct = path_data + '/scratches'
crz_xpl = 'C:/Users/m477a/JupyterNote/task_prof_tsou/NEU Surface Defect Database/IMAGES/train/crazing/crazing_1.jpg'
inc_xpl = 'C:/Users/m477a/JupyterNote/task_prof_tsou/NEU Surface Defect Database/IMAGES/train/inclusion/inclusion_1.jpg'
ptc_xpl = 'C:/Users/m477a/JupyterNote/task_prof_tsou/NEU Surface Defect Database/IMAGES/train/patches/patches_1.jpg'
pts_xpl = 'C:/Users/m477a/JupyterNote/task_prof_tsou/NEU Surface Defect Database/IMAGES/train/pitted_surface/pitted_surface_1.jpg'
rds_xpl = 'C:/Users/m477a/JupyterNote/task_prof_tsou/NEU Surface Defect Database/IMAGES/train/rolled-in_scale/rolled-in_scale_1.jpg'
sct_xpl = 'C:/Users/m477a/JupyterNote/task_prof_tsou/NEU Surface Defect Database/IMAGES/train/scratches/scratches_1.jpg'

# %%
num_crz = len(os.listdir(crz))
num_inc = len(os.listdir(inc))
num_ptc = len(os.listdir(ptc))
num_pts = len(os.listdir(pts))
num_rds = len(os.listdir(rds))
num_sct = len(os.listdir(sct))

# %%
# see the data class or separated files
os.listdir(path_data)
# Out:
# ['crazing',
#  'inclusion',
#  'patches',
#  'pitted_surface',
#  'rolled-in_scale',
#  'scratches']

# %%
# to see the images number in each files
print('total data crazing images        :', num_crz)
print('total data inclusion images      :', num_inc)
print('total data patches images        :', num_ptc)
print('total data pitted_surface images :', num_pts)
print('total data rolled-in_scale images:', num_rds)
print('total data scratches images      :', num_sct)
print('total all data                   :', num_crz + num_inc + num_ptc + num_pts + num_rds + num_sct)
# Out:
# total data crazing images        : 295
# total data inclusion images      : 296
# total data patches images        : 295
# total data pitted_surface images : 294
# total data rolled-in_scale images: 295
# total data scratches images      : 295
# total all data                   : 1770

# %%
image_crz_names = os.listdir(path_data + '/crazing')
image_inc_names = os.listdir(path_data + '/inclusion')
image_ptc_names = os.listdir(path_data + '/patches')
image_pts_names = os.listdir(path_data + '/pitted_surface')
image_rds_names = os.listdir(path_data + '/rolled-in_scale')
image_sct_names = os.listdir(path_data + '/scratches')

# %%
# see the 5 first data in crazing data file
print(image_crz_names[:5])
# Out:
# ['crazing_1.jpg', 'crazing_10.jpg', 'crazing_100.jpg', 'crazing_101.jpg', 'crazing_102.jpg']

# %%
# see the 5 first data in inclusion data file
print(image_inc_names[:5])
# Out:
# ['inclusion_1.jpg', 'inclusion_10.jpg', 'inclusion_100.jpg', 'inclusion_101.jpg', 'inclusion_102.jpg']

# %%
# see the 5 first data in patches data file
print(image_ptc_names[:5])
# Out:
# ['patches_1.jpg', 'patches_10.jpg', 'patches_100.jpg', 'patches_101.jpg', 'patches_102.jpg']

# %%
# see the 5 first data in pitted surface data file
print(image_pts_names[:5])
# Out:
# ['pitted_surface_1.jpg', 'pitted_surface_10.jpg', 'pitted_surface_100.jpg', 'pitted_surface_101.jpg', 'pitted_surface_102.jpg']

# %%
# see the 5 first data in rolled in scale data file
print(image_rds_names[:5])
# Out:
# ['rolled-in_scale_1.jpg', 'rolled-in_scale_10.jpg', 'rolled-in_scale_100.jpg', 'rolled-in_scale_101.jpg', 'rolled-in_scale_102.jpg']

# %%
# see the 5 first data in scratches data file
print(image_sct_names[:5])
# Out:
# ['scratches_1.jpg', 'scratches_10.jpg', 'scratches_100.jpg', 'scratches_101.jpg', 'scratches_102.jpg']

# %% [markdown]
# ### Crazing

# %%
pic_crz = load_img(crz_xpl)
display(pic_crz)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x25F794D3490>

# %%
pic_array = img_to_array(pic_crz)
pic_array.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# ### Inclusion

# %%
pic_inc = load_img(inc_xpl)
display(pic_inc)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x25F7958FAF0>

# %%
pic_array = img_to_array(pic_inc)
pic_array.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# ### Patches

# %%
pic_ptc = load_img(ptc_xpl)
display(pic_ptc)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x25F7958FB80>

# %%
pic_array = img_to_array(pic_ptc)
pic_array.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# ### Pitted surface

# %%
pic_pts = load_img(pts_xpl)
display(pic_pts)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x25F795972B0>

# %%
pic_array = img_to_array(pic_pts)
pic_array.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# ### Rolled in scale

# %%
pic_rds = load_img(rds_xpl)
display(pic_rds)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x25F79597880>

# %%
pic_array = img_to_array(pic_rds)
pic_array.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# ### Scratches

# %%
pic_sct = load_img(sct_xpl)
display(pic_sct)
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=200x200 at 0x25F7959F550>

# %%
pic_array = img_to_array(pic_sct)
pic_array.shape
# Out:
# (200, 200, 3)

# %% [markdown]
# ### Images as 3D Arrays
# An image can be stored as a three-dimensional array in memory.
#
# Typically, the image format has one dimension for rows (height), one for columns (width) and one for channels.
#
# If the image is black and white (grayscale), the channels dimension may not be explicitly present, e.g. there is one unsigned integer pixel value for each (row, column) coordinate in the image.
#
# Colored images typically have three channels, for the pixel value at the (row, column) coordinate for the red, green, and blue components.
#
# Deep learning neural networks require that image data be provided as three-dimensional arrays.
#
# This applies even if your image is grayscale. In this case, the additional dimension for the single color channel must be added.
#
# There are two ways to represent the image data as a three dimensional array. The first involves having the channels as the last or third dimension in the array. This is called “channels last“. The second involves having the channels as the first dimension in the array, called “channels first“.
#
# - **Channels Last**. Image data is represented in a three-dimensional array where the last channel represents the color channels, e.g. [rows][cols][channels].
#
# - **Channels First**. Image data is represented in a three-dimensional array where the first channel represents the color channels, e.g. [channels][rows][cols].
#
# Some image processing and deep learning libraries prefer channels first ordering, and some prefer channels last. As such, it is important to be familiar with the two approaches to representing images.

# %% [markdown]
# from the shape we can see that for every images are in the same dimension which **(heigh x width x channels)** so we can get that for every image in the data set that the size of image such 200 heigh x 200 width x 3 channels and also that Deep learning neural network require that image data provided as 3 dimensional array the 3 in the channels also have meaning three color channels R, G, B

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 8
next_crz_pix = [os.path.join(path_data + '/crazing', fname) 
                for fname in image_crz_names[pic_index-8:pic_index]]

next_inc_pix = [os.path.join(path_data + '/inclusion', fname) 
                for fname in image_inc_names[pic_index-8:pic_index]]

# next_ptc_pix = [os.path.join(path_data + '/patches', fname) 
#                 for fname in image_inc_names[pic_index-8:pic_index]]

# next_pts_pix = [os.path.join(path_data + '/pitted_surface', fname) 
#                 for fname in image_inc_names[pic_index-8:pic_index]]

# next_rds_pix = [os.path.join(path_data + '/rolled-in_scale', fname) 
#                 for fname in image_inc_names[pic_index-8:pic_index]]

# next_sct_pix = [os.path.join(path_data + '/scratches', fname) 
#                 for fname in image_inc_names[pic_index-8:pic_index]]

for i, img_path in enumerate(next_crz_pix + next_inc_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1) 
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()
